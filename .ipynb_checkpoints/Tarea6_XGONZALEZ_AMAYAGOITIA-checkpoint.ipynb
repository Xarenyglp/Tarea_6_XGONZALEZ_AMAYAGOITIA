# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Xareny González López, Jose Alberto Mayagoitia Gutierrez.
#
# **Fecha:** 12 de octubre del 2021.
#
# **Expediente** : if720811, if720266
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/Xarenyglp/Tarea_6_XGONZALEZ_AMAYAGOITIA
#
# # Tarea 6: Clase 10

# %% [markdown]
# Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:

# %% [markdown]
# ### Ejercicio 1:
# 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.

# %%
#librerias
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Código de solución estudiante 1

# %%
# Código de solución estudiante 1
def f(x):
    return 30*(x**2 -2*x**3 + x**4)

def t(x):
    return(a * np.sin(np.pi * x))

x = np.linspace(0,1,101)
f_x = list(map(f,x))

a = float(f(optimize.fmin(lambda x:-f(x),0,disp=False)))
print('El máximo de la función es:', a)

t_x = list(map(t,x))

plt.plot(f_x);
plt.plot(t_x);
# Out:
# El máximo de la función es: 1.875

# %% [markdown]
# Código de solución estudiante 2

# %%
from scipy.stats import erlang
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
# %matplotlib inline

# %%
# Código de solución estudiante 2
# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))
# Función t -> Función constante
t = lambda x: max_f*np.sin(np.pi*x) # función constante

x = np.arange(0,1,0.01)  # Rango donde se graficará las funciones
print('El máximo de f es:',max_f)
# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()
plt.show()
# Out:
# El máximo de f es: [1.875]

# %% [markdown]
# ### Ejercicio 2:
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).

# %% [markdown]
# Código de solución estudiante 1

# %% [markdown]
# $$g(x)=\frac{t(x)}{c}$$
# $$f(x)=30(x^2-2x^3+x^4)$$
# $$t(x)=a \sin(\pi x)$$
#
# $$a=max(f(x))$$
#
# $$c=\int_{0}^{1}a sin(\pi x)dx$$
#
# $$c=max(f(x))\int_{0}^{1} sin(\pi x)dx$$
# $$c= max(f(x))* [-\frac{cos(\pi y)}{\pi} ]_{0}^{1} = \frac{2}{\pi}max(f(x))$$
#
# $$g(x)=\frac{t(x)}{c}=\frac{max(f(x)) \sin(\pi x)}{\frac{2}{\pi}max(f(x))}=\frac{\pi sin(\pi x)}{2}$$

# %% [markdown]
# Código de solución estudiante 2

# %% [markdown]
# Usando Markdown
# $$g(x)=\frac{t(x)}{c}$$
# $$f(x)=30(x^2-2x^3+x^4)$$
# $$t(x)=a \sin(\pi x)$$
#
# $$a=max(f(x))$$
#
# $$c=\int_{0}^{1}a sin(\pi x)dx$$
#
# $$c=max(f(x))\int_{0}^{1} sin(\pi x)dx$$
# $$c= max(f(x))* [-\frac{cos(\pi y)}{\pi} ]_{0}^{1} = \frac{2}{\pi}max(f(x))$$
#
# $$g(x)=\frac{t(x)}{c}=\frac{max(f(x)) \sin(\pi x)}{\frac{2}{\pi}max(f(x))}=\frac{\pi sin(\pi x)}{2}$$

# %% [markdown]
# ### Ejercicio 3:
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).

# %% [markdown]
# Código de solución estudiante 1

# %% [markdown]
# $$G(x)= \int_{0}^{x} g(x)dx = \frac{1}{2} \int_{0}^{x} sin(\pi x)$$
#
# $$G(x)=-\frac{1}{2} [cos(\pi x)]^{x}_{0}= \frac{1}{2} (1-cos(\pi x))$$
#
# $$U= \frac{1}{2} (1-cos(\pi x))$$
#
# Despejamos
#
#
# $$x=2U=(1-cos(\pi x)$$
#
# $$cos(\pi x)+2U =1 $$
#
# $$cos(\pi x)=1 - 2U  $$
#
# $$\pi x= arcos(1 - 2U)  $$
#
# $$x= \frac{arcos(1 - 2U)}{\pi }  $$

# %% [markdown]
# Código de solución estudiante 2

# %% [markdown]
# $$G(x)= \int_{0}^{x} g(x)dx = \frac{1}{2} \int_{0}^{x} sin(\pi x)$$
#
# $$G(x)=-\frac{1}{2} [cos(\pi x)]^{x}_{0}= \frac{1}{2} (1-cos(\pi x))$$
#
# $$U= \frac{1}{2} (1-cos(\pi x))$$
#
# Despejamos
#
#
# $$x=2U=(1-cos(\pi x)$$
#
# $$cos(\pi x)+2U =1 $$
#
# $$cos(\pi x)=1 - 2U  $$
#
# $$\pi x= arcos(1 - 2U)  $$
#
# $$x= \frac{arcos(1 - 2U)}{\pi }  $$

# %% [markdown]
# ### Ejercicio 4:
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:
# ![descarga.png](attachment:descarga.png)

# %% [markdown]
# Código de solución estudiante 1

# %%
# Código de solución estudiante 1
x = np.arange(0, 1, 0.01)

def f(x):
    return 30*(x**2-2*x**3+x**4)

def t(x):
    return c*np.sin(np.pi*x)

def g(u):
    return np.pi/2*np.sin(np.pi*u)

N = 10000
R2 = np.random.rand(N)
u = np.random.uniform(0, 1, N)

R1 =  (np.arccos(-2*u+1))/(np.pi) 

plt.hist(R1, 50, density = True)
plt.plot(x, g(x), lw = 3)
plt.show()

# %% [markdown]
# Código de solución estudiante 2

# %%
import scipy.optimize as opt
import math

# %%
# Código de solución estudiante 2
def aleatorios(N):
    z =np.random.uniform(0,2/np.pi,N)
    y=list(map(lambda x: (1/np.pi)*np.arccos(1-np.pi*z[x]),range(N)))
    return y

# %%
N = 10**4

def histograma(N):
    r1=aleatorios(N)
    y,x,_=plt.hist(r1, bins=50,density=True)
    y2 =(np.pi*np.sin(np.pi*x))/2 
    plt.plot(x,y2,'r-')
    plt.show()                    

histograma(N)

# %% [markdown]
# ### Ejercicio 5:
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Código de solución estudiante 1

# %%
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# %%
# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)

max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))

t = lambda x: max_f*np.sin(np.pi*x) 


x = np.arange(0,1,0.01)  
print('El máximo de f es:',max_f)

# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 500 
R2 = np.random.rand(N)
R1 = np.arccos(1-2*np.random.rand(N))/np.pi

Acep_rechazo(R2, R1, f, t)
# Out:
# El máximo de f es: [1.875]

# %% [markdown]
# Código de solución estudiante 2

# %%
# Código de solución estudiante 2
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# %%
# Ilustración del método de aceptación y rechazo cuando se toma t(x) constante

# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))
# Función t 
t = lambda x: max_f*np.sin(np.pi*x) 

# Rango donde se graficará las funciones
x = np.arange(0,1,0.01)  
print('El máximo de f es:',max_f)

# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 500 # Puntos aleatorios
R2 = np.random.rand(N)
R1 = np.arccos(1-2*np.random.rand(N))/np.pi

Acep_rechazo(R2, R1, f, t)
# Out:
# El máximo de f es: [1.875]

# %% [markdown]
# ### Ejercicio 6:
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %% [markdown]
# Código de solución estudiante 1

# %%
# Código de solución estudiante 1
def Acep_rech2(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):

    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    cont=np.asarray([1 if condition[i] else 0 for i in range(len(R1))]).sum()
    return cont

res=(Acep_rech2(R2,R1,f,t)/len(R1))*100
res
print('El porcentaje de puntos de aceptación es de:', res, 'con pulso senoidal')
# Out:
# El porcentaje de puntos de aceptación es de: 82.6 con pulso senoidal

# %%
R_1=np.random.rand(N)
R_2=np.random.rand(N)
res_2=(Acep_rech2(R_1,R_2,f,t)/len(R1))*100
res_2
print('El porcentaje de puntos de aceptación es de:', res_2, 'con constante')
# Out:
# El porcentaje de puntos de aceptación es de: 74.8 con constante

# %% [markdown]
# En conlusion cuando utilizamos el pulso senoidal los puntos que son aceptados son algo mayores a los que se obtienen cuando t(x) es constante, ya que en el pulso senoidal nuestra funcion es parecida.

# %% [markdown]
# Código de solución estudiante 2

# %%
# Código de solución estudiante 2
# Función de aceptación y rechazo cuando se usa t(x) un pulso senoidal
def Acep_rech2(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    cont=np.asarray([1 if condition[i] else 0 for i in range(len(R1))]).sum()
    return cont

res=(Acep_rech2(R2,R1,f,t)/len(R1))*100
res
# Out:
# 82.6

# %%
print('El porcentaje de puntos de aceptación es de:', res, 'con pulso senoidal')
# Out:
# El porcentaje de puntos de aceptación es de: 82.6 con pulso senoidal

# %%
# Función de aceptación y rechazo cuando se usa t(x) constante
R_1=np.random.rand(N)
R_2=np.random.rand(N)
res_2=(Acep_rech2(R_1,R_2,f,t)/len(R1))*100
res_2
# Out:
# 67.2

# %%
print('El porcentaje de puntos de aceptación es de:', res_2, 'con constante')
# Out:
# El porcentaje de puntos de aceptación es de: 67.2 con constante

# %% [markdown]
# Concluimos que con pulso senoidal los puntos que son aceptados son algo mayores a los que se obtienen cuando t(x) es constante, ya que en el pulso senoidal nuestra funcion es parecida.

# %% [markdown]
# ### Ejercicio 7:
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo

# %% [markdown]
# Código de solución estudiante 1

# %%
plt.figure(figsize=[8,6])
plt.title('Método Aceptación y Rechazo',fontsize=15)
w = lambda x: 20*x*(1-x)**3
y = w(optimize.fmin(lambda x:-w(x), 0, disp=False))
z = lambda x: y*np.ones([len(x)])
plt.plot(x,w(x), label='$w(x)=20x(1-x)^3$')
plt.plot(x,z(x),label='$z(x)=y$')
plt.legend(loc="best");
N = 500 
rdm = np.random.rand(N)
rdmu = np.random.uniform(0,1, size=N)
ac_r = Acep_rechazo(rdm,rdmu,w,z)

# %% [markdown]
# Código de solución estudiante 2

# %%
plt.figure(figsize=[8,6])
plt.title('Método Aceptación y Rechazo',fontsize=15)
w = lambda x: 20*x*(1-x)**3
y = w(optimize.fmin(lambda x:-w(x), 0, disp=False))
z = lambda x: y*np.ones([len(x)])
plt.plot(x,w(x), label='$w(x)=20x(1-x)^3$')
plt.plot(x,z(x),label='$z(x)=y$')
plt.legend(loc="best");
N = 500 
rdm = np.random.rand(N)
rdmu = np.random.uniform(0,1, size=N)
ac_r = Acep_rechazo(rdm,rdmu,w,z)

# %% [markdown]
# ### Ejercicio 8:
# 8. Demostrar la validez de la siguiente ecuación
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i$$

# %% [markdown]
# #### Código de solución estudiante 1

# %% [markdown]
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i =\frac{\frac{n! p ^ {i+1} (1-p)^{n-i+1}}{(i+1)!(n-i+1)!}}{\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i}}$$

# %% [markdown]
# Por lo tanto, desarrollando y eliminando el factor común obtenemos lo siguiente:

# %% [markdown]
# $$\frac{p_{i+1}}{p_i} =\frac{p(n-i)!}{(1-p)(i+1)!(n-i-1)!}$$
#
# $$p_{i+1} = \frac{n-i}{i+1}\frac{p}{1-p}p_i$$

# %% [markdown]
# #### Código de solución estudiante 2

# %% [markdown]
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i =\frac{\frac{n! p ^ {i+1} (1-p)^{n-i+1}}{(i+1)!(n-i+1)!}}{\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i}}$$
#
# $$\frac{p_{i+1}}{p_i} =\frac{p(n-i)!}{(1-p)(i+1)!(n-i-1)!}$$
#
# $$p_{i+1} = \frac{n-i}{i+1}\frac{p}{1-p}p_i$$

# %% [markdown]
# > Ventaja de ecuacion recursiva: Menor carga computacional

# %% [markdown]
# ### Ejercicio 9:
# 9. Seguir un procedimiento similar al mostrado cuando se generó una distribución binomial, pero en esta caso genere un código que genere variables aletorias Poisson cuya función de distribución de probabilidad esta dada por:
# $$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$$
# Demuestre matemáticamente que
#  $$P(k+1)=\frac{\lambda}{k+1}P(k)$$
#  y a partir de esta relación genere variables aletorias que distribuyen poisson usando el método de la transformada inversa.

# %% [markdown]
# #### Código de solución estudiante 1

# %% [markdown]
# $$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$$
# $$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^{k+1}}{(k+1)!}$$
# $$P_{k+1} = \frac{\lambda}{k+1}P_{k}$$

# %%
N=1000
x=20

def Poisson_Dist(x, N): 
    v = np.zeros(N)
    v[0] = np.exp(-x)
    
    def vr(i):
        nonlocal v
        v[i+1] = (x*v[i])/(i+1) 
    [vr(i) for i in range(N-1)]
    return v.cumsum()

def p_a(p_acc, N):
    y = np.random.rand(N)
    p_a = [sum([1 for p in p_acc if p < i ])  for i in y]
    return p_a

p_acc = Poisson_Dist(x,N) 
distribution = p_a(p_acc, N) 

plt.figure(figsize=[8,4])
y, x = np.histogram(distribution,bins = len(set(distribution))) 
plt.bar(list(set(distribution)), y, label="Poisson Distribution")
plt.legend(loc = "best")
plt.grid()
plt.show()

# %% [markdown]
# #### Código de solución estudiante 2

# %% [markdown]
# $$\frac{P(k+1)}{P(k)} = \frac{\frac{e^{-\lambda}(\lambda)^{k+1}}{(k+1)!}}{\frac{e^{-\lambda}(\lambda)^k}{k!}}$$
# $$\frac{k!}{(k+1)!}=\frac{1}{k+1}$$
# $$\frac{P(k+1)}{P(k)} = \frac{\lambda^{k+1}k!}{\lambda^{k}(k+1)!} = \frac{\lambda}{k+1}$$
# $$P(k+1) = \frac{\lambda}{k+1}P(k)$$

# %%
N=1000
x=20

def Poisson_Dist(x, N): 
    v = np.zeros(N)
    v[0] = np.exp(-x)
    
    def vr(i):
        nonlocal v
        v[i+1] = (x*v[i])/(i+1) 
    [vr(i) for i in range(N-1)]
    return v.cumsum()

def p_a(p_acc, N):
    y = np.random.rand(N)
    p_a = [sum([1 for p in p_acc if p < i ])  for i in y]
    return p_a

p_acc = Poisson_Dist(x,N) 
distribution = p_a(p_acc, N) 

plt.figure(figsize=[8,4])
y, x = np.histogram(distribution,bins = len(set(distribution))) 
plt.bar(list(set(distribution)), y, label="Poisson Distribution")
plt.legend(loc = "best")
plt.grid()
plt.show()
